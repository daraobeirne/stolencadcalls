# %%
import ijson
import pandas as pd
import numpy as np
from pyproj import Proj, transform
import folium
from folium import plugins

filename = 'cadcalls.json'
with open(filename, 'r') as f:
    objects = ijson.items(f, "item")
    columns = list(objects)
    
print(columns[0].keys())
# Out:
# dict_keys(['Record ID', 'Call Type', 'Description', 'Reporting Officer', 'Unit ID', 'Report Created', 'Location', 'Police District', 'Beat', 'Grid', 'X Coordinate', 'Y Coordinate', 'Day of Week', 'Occurence Date', 'Occurence Time', 'Received Date', 'Received Time', 'Dispatch Date', 'Dispatch Time', 'Enroute Date', 'Enroute Time', 'At Scene Date', 'At Scene Time', 'Clear Date', 'Clear Time'])

# %%
column_names = list(columns[0].keys())
print(column_names)
# Out:
# ['Record ID', 'Call Type', 'Description', 'Reporting Officer', 'Unit ID', 'Report Created', 'Location', 'Police District', 'Beat', 'Grid', 'X Coordinate', 'Y Coordinate', 'Day of Week', 'Occurence Date', 'Occurence Time', 'Received Date', 'Received Time', 'Dispatch Date', 'Dispatch Time', 'Enroute Date', 'Enroute Time', 'At Scene Date', 'At Scene Time', 'Clear Date', 'Clear Time']

# %%
data = []
with open(filename, 'r') as f:
    objects = ijson.items(f, 'item')
    for row in objects:
        selected_row = []
        for item in column_names:
            selected_row.append(row[item])
        data.append(selected_row)
        
print(data[1])
# Out:
# ['6167911', '952PP', 'INCOMPLETE CALL FROM PAY PHONE', '', '', 'N', '1115 3RD ST', '3', '3M', '0742', '6703668', '1973944', 'Fri', '01/01/2016', '02:12:47', '01/01/2016', '02:12:47', '', '', '', '', '', '', '01/01/2016', '02:22:59']

# %%
calls = pd.DataFrame(data, columns=column_names)

calls['Description'].value_counts()
# Out:
# DISTURBANCE-CLARIFY                                  37286
# TRAFFIC STOP                                         26872
# SUSPICIOUS SUBJECT/CIRCUMSTANCE-IN PROGRESS          22151
# SUBJECT STOP                                         19391
# ALL UNITS BROADCAST                                  19266
# INCOMPLETE CALL FOR POLICE                           16634
# WELFARE CHECK                                        15487
# SUSPICIOUS OCCUPIED VEHICLE                          15068
# ALARM-SECURE NO EVID OF CRIME                         8175
# ERRAND                                                7316
# BUSINESS CHECK                                        6961
# MISDEMEANOR ASSAULT-IN PROGRESS                       6844
# ALARM-CANCEL                                          6020
# REPORT NUMBER ASSIGNMENT                              5670
# VEHICLE ACCIDENT-NO OR UNKNOWN INJURIES               5416
# DISTURBANCE-NOISE                                     5176
# DISTURBANCE-FAMILY                                    4922
# ALARM-ACCIDENTAL                                      4628
# PARK CHECK                                            4588
# CHECK ON HAZARD                                       4297
# VEHICLE ACCIDENT-WITH INJURIES                        4087
# STOLEN VEHICLE-REPORT                                 3720
# MEDICAL AID-CLARIFY IN TEXT                           3514
# SHOTS FIRED - LESS THAN 15 AGO                        3505
# ALARM-ADVISED FULL RESPONSE                           3480
# ATTEMPT PICKUP/WARRANT SERVICE                        2943
# SUPPLEMENTAL EMPLOYMENT                               2891
# DOMESTIC VIOLENCE-IN PROGRESS                         2631
# SUSPICIOUS SUBJECT/CIRCUMSTANCE-LESS THAN 15 AGO      2297
# BURGLARY-REPORT                                       2197
#                                                      ...
# PANIC ALARM-VEHICLE                                     29
# RAPE-IN PROGRESS                                        27
# SEX CRIMES-CSI                                          24
# MEDICAL AID-SUSPECT ON SCENE                            23
# KIDNAPPING-IN PROGRESS                                  22
# SHOOTING INTO UNOCCUPIED VEHICLE-LESS THAN 15 AGO       22
# KIDNAPPING-CSI                                          18
# GRAND THEFT-LESS THAN 5 AGO                             18
# DEAD BODY-CSI                                           16
# LOCAL GOVERNMENT-GENERAL                                14
# GRAND THEFT-IN PROGRESS                                 14
# CAR CLOUT-CSI                                           12
# LOCAL GOVERNMENT TREE DOWN/BLOCKING                     11
# BOMB THREAT                                              9
# MISDEMEANOR HIT & RUN-CSI                                9
# GRAND THEFT-CSI                                          8
# CARJACKING IN PROGRESS                                   7
# DIRECTED PATROL-AVAILABLE                                6
# PETTY THEFT-CSI                                          5
# REFER TO OUTSIDE AGENCY                                  4
# POSSESSION OF STOLEN PROPERTY-CSI                        4
# EXPLOSIVE DEVICE-CSI                                     4
# HOMICIDE                                                 4
# SHOOTING INTO INHABITED DWELLING-IN PROGRESS             4
# DIRECTED PATROL-POP-NOT AVAIL                            4
# SHOOTING INTO UNOCCUPIED VEHICLE-IN PROGRESS             3
# ARSON-CSI                                                3
# NARCOTIC ACTIVITY-CSI                                    2
# CARJACKING-LESS THAN 15 AGO - WITH INJURIES              2
# BURGLARY-REPORT-VERIFIED                                 1
# Name: Description, dtype: int64

# %%
calls['Day of Week'].value_counts()
# Out:
# Fri    51619
# Thu    49484
# Wed    48426
# Tue    48107
# Sat    47934
# Mon    44964
# Sun    41979
# Name: Day of Week, dtype: int64

# %%
def parse_float(x):
    try:
        x = float(x)
    except Exception:
        x = 0
    return x
calls['X Coordinate'] = calls['X Coordinate'].apply(parse_float)
calls['Y Coordinate'] = calls['Y Coordinate'].apply(parse_float)

# %%
stolen = calls[calls['Description'] == 'STOLEN VEHICLE-REPORT']

print(stolen)
# Out:
#        Record ID Call Type            Description Reporting Officer Unit ID  \
# 103      5896362    503RPT  STOLEN VEHICLE-REPORT              0326   EXP60
# 149      5895748    503RPT  STOLEN VEHICLE-REPORT
# 319      5896213    503RPT  STOLEN VEHICLE-REPORT              6201
# 708      5895633    503RPT  STOLEN VEHICLE-REPORT
# 894      5924237    503RPT  STOLEN VEHICLE-REPORT              6252
# 1639     5898084    503RPT  STOLEN VEHICLE-REPORT              0326   EXP60
# 1824     5898357    503RPT  STOLEN VEHICLE-REPORT              0326   EXP60
# 2198     5898642    503RPT  STOLEN VEHICLE-REPORT
# 2284     5906544    503RPT  STOLEN VEHICLE-REPORT              6256
# 2435     5899077    503RPT  STOLEN VEHICLE-REPORT             R6262
# 2623     5899962    503RPT  STOLEN VEHICLE-REPORT              8122
# 332334   6388582    503RPT  STOLEN VEHICLE-REPORT              6253
# 332335   6378044    503RPT  STOLEN VEHICLE-REPORT              6253
# 332454   6359669    503RPT  STOLEN VEHICLE-REPORT              6252
# 332468   6359479    503RPT  STOLEN VEHICLE-REPORT              6229
# 332469   6359264    503RPT  STOLEN VEHICLE-REPORT              6229
# 332473   6359048    503RPT  STOLEN VEHICLE-REPORT              6253
# 332510   6360410    503RPT  STOLEN VEHICLE-REPORT               217    2A51
#
#        Report Created                               Location Police District  \
# 103                 N                    6219 RIVERSIDE BLVD               4
# 149                 N                         5340 ALCOTT DR               6
# 319                 N                          3241 32ND AVE               4
# 708                 N                              2100 J ST               3
# 894                 N                          4429 WYMAN DR              UI
# 1639                N                        5350 JACKSON ST              UI
# 1824                N                   7489 PHOENIX PARK DR               5
# 2198                N                     7865 LA RIVIERA DR               6
# 2284                Y                             1 SHOAL CT               4
# 2435                Y           NORTHGATE BLVD / SAN JUAN RD               1
# 2623                N                    2573 RIO LINDA BLVD               2
# 2751                Y                         1896 ARDEN WAY               2
# 2789                N                          3241 32ND AVE               4
# 3207                N                    4200 E COMMERCE WAY               1
# 3350                N                          300 BERCUT DR               3
# 3984                N                        2319 N MANOR DR               5
# 4511                N                     7551 FRANKLIN BLVD               5
# 5534                N                         12TH ST / J ST               3
# 5724                N                               600 J ST               3
# 6078                N                           2845 37TH ST               6
# 6631                N                     2667 DEL PASO BLVD               2
# 7281                Y                    6099 S LAND PARK DR               4
# 7854                N                          H ST / 9TH ST               3
# 8093                N                          7388 MANDY DR               5
# 8299                N                          2076 20TH AVE               4
# 9096                Y                39TH AVE / POWER INN RD               6
# 9185                N                          3825 ROSIN CT               1
# 9584                N                  MACK RD / CENTER PKWY               5
# 10190               N                          209 CINEMA ST               5
# 10289               N                        3515 ELKART WAY               1
# ...               ...                                    ...             ...
# 331897              N                         1896 ARDEN WAY               2
# 331916              Y                       5920 OUTFALL CIR               6
# 331932              Y                        7910 NEWGATE DR               5
# 331981              Y                     8173 BELVEDERE AVE               6
# 331987              Y                          1479 65TH AVE               5
# 332034              Y                         640 NORGARD CT               1
# 332045              Y                              1001 I ST               3
# 332048              Y                      2695 FAIRFIELD ST               2
# 332052              Y                    8653 GOLDEN SAGE DR              UI
# 332066              Y                           11 QUINTA CT               5
# 332081              Y                         3732 BELDEN ST               2
# 332082              Y                           1025 16TH ST               3
# 332085              Y                         7021 ALCOTT DR               6
# 332104              Y                LUNA NUEVO ST / FORD RD               2
# 332123              Y                          307 NIMITZ ST               2
# 332128              Y  12TH AVE / MARTIN LUTHER KING JR BLVD               6
# 332136              Y                     1205 LAMBERTON CIR               2
# 332182              N                             721 N B ST               3
# 332251              Y                          2830 BROADWAY               4
# 332278              Y                     7408 FRANKLIN BLVD               5
# 332295              Y                           3619 60TH ST               6
# 332313              Y                          6423 14TH AVE               6
# 332333              Y                            1500 7TH ST               3
# 332334              Y                    2394 NORTHGATE BLVD               1
# 1639    01/03/2016   16:08:58
# 1824    01/03/2016   21:14:51
# 2198    01/04/2016   06:37:31
# 2284    01/04/2016   18:00:41
# 2435    01/04/2016   13:39:55
# 2623    01/05/2016   07:40:46
# 2751    01/04/2016   18:27:57
# 2789    01/05/2016   00:34:12
# 3207    01/05/2016   18:02:25
# 3350    01/06/2016   15:00:59
# 3984    01/06/2016   02:07:43
# 4511    01/07/2016   12:58:21
# 5534    01/08/2016   18:00:37
# 5724    01/08/2016   20:14:02
# 6078    01/09/2016   09:21:31
# 6631    01/10/2016   18:16:33
# 7281    01/11/2016   08:42:55
# 7854    01/13/2016   01:24:10
# 8093    01/13/2016   03:03:16
# 8299    01/12/2016   15:51:45
# 9096    01/13/2016   19:42:23
# 9185    01/13/2016   20:37:51
# 9584    01/14/2016   19:36:51
# 10190   01/15/2016   23:07:47
# 10289   01/15/2016   18:19:37
# ...            ...        ...
# 331897  12/27/2016   00:26:08
# 331916  12/26/2016   11:03:07
# 331932  12/26/2016   07:51:08
# 331981  12/27/2016   10:38:02
# 331987  12/27/2016   13:29:35
# 332034  12/27/2016   08:01:51
# 332045  12/27/2016   18:28:55
# 332048  12/27/2016   07:33:23
# 332052  12/28/2016   00:01:58
# 332066  12/29/2016   15:18:11
# 332081  12/28/2016   01:44:33
# 332082  01/05/2017   17:23:52
# 332085  12/28/2016   08:11:30
# 332104  12/28/2016   18:42:26
# 332123  12/29/2016   11:39:18
# 332128  12/28/2016   11:43:23
# 332136  12/28/2016   16:46:23
# 332182  12/28/2016   17:37:16
# 332251  12/29/2016   15:40:16
# 332278  12/29/2016   08:52:29
# 332295  12/29/2016   07:37:37
# 332313  12/29/2016   09:14:39
# 332333  12/29/2016   18:32:37
# 332334  12/29/2016   18:56:47
# 332335  12/29/2016   17:43:16
# 332454  12/31/2016   17:24:21
# 332468  12/31/2016   10:27:56
# 332469  12/31/2016   09:01:21
# 332473  12/31/2016   00:11:04
# 332510  01/01/2017   04:21:53
#
# [3720 rows x 25 columns]

# %%
inProj = Proj(init='epsg:2226', preserve_units = True)
outProj = Proj(init='epsg:4326')
x1,y1 = 6722570,1992314
x2,y2 = transform(inProj,outProj,x1,y1)
print(x2,y2)
# Out:
# -121.43672656313065 38.63153998649104

# %%
calls_map = folium.Map(location=[38.58, -121.5], zoom_start=10)
marker_cluster = folium.MarkerCluster().add_to(calls_map)
coords_list = []
for name, row in stolen.iloc[:1000].iterrows():   
    x1, y1 =row['X Coordinate'],row['Y Coordinate']
    long, lat = transform(inProj,outProj,x1,y1)
    coords = (lat,long)
    coords_list.append(coords)
    folium.Marker([lat, long], popup=row["Description"]).add_to(marker_cluster)
calls_map.save('callsnew.html')
calls_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
calls_heatmap = folium.Map(location=[38.58, -121.5], tiles='Stamen Toner', zoom_start=12)
calls_heatmap.add_child(plugins.HeatMap([[item[0], item[1]] for item in coords_list]))
calls_heatmap.save("heatmap.html")
calls_heatmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
